# %% [markdown]
# # [Dirty data to clean What"s wrong with this dataset](https://www.kaggle.com/datasets/joannanplkrk/dirty-data-to-clean-whats-wrong-with-this-dataset)

# %%
# !pip install pandas numpy matplotlib seaborn folium
# Out:
# Requirement already satisfied: pandas in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: numpy in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: seaborn in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: folium in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: branca>=0.6.0 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from requests->folium) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrey/Ground/25AIMEPhI/.venv/lib/python3.13/site-packages (from requests->folium) (2025.8.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import Marker, Map
from folium.plugins import HeatMap

# %%
df = pd.read_csv("wrecked_data/animal_data_dirty1.csv", sep=';')
df
# Out:
#           Animal type  Country  Weight kg  Body Length cm          Gender  \
# 0                 NaN      NaN        NaN             NaN             NaN
# 1                 NaN      NaN        NaN             NaN             NaN
# 2      European bison   Poland    930.000           335.0            male
# 3      European bison   Poland    909.000           311.0  not determined
# 4     European bison™   Poland    581.000           277.0          female
# ...               ...      ...        ...             ...             ...
# 1006     red squirrel   Poland      0.346            20.0          female
# 1007         hedgehog  Germany      1.000            23.0          female
# 1008         hedgehog  Germany      0.500            17.0          female
# 1009     red squirrel   Poland      0.346            20.0          female
# 1010         hedgehog  Hungary      0.900            16.0          female
#
#       Animal code   Latitude  Longitude Animal name Observation date  \
# 0             NaN        NaN        NaN         NaN       03.01.2024
# 1             NaN        NaN        NaN         NaN       03.02.2024
# 2             NaN  52.828845  23.820144       Szefu       01.03.2024
# 3             NaN  52.830509  23.826849         NaN       01.03.2024
# 4             NaN  52.834109  23.807093         NaN       01.03.2024
# ...           ...        ...        ...         ...              ...
# 1006          NaN  52.212001  21.033187        Lola       7 May 2024
# 1007          NaN  49.561356  11.105334         NaN       7 May 2024
# 1008          NaN  49.561569  11.087046         NaN       7 May 2024
# 1009          NaN  52.212001  21.033187        Lola       7 May 2024
# 1010          NaN  47.509860  18.939943         NaN       8 May 2024
#
#      Data compiled by
# 0       James Johnson
# 1       James Johnson
# 2        Anne Anthony
# 3        Anne Anthony
# 4        Anne Anthony
# ...               ...
# 1006     Anne Anthony
# 1007       Bob Bobson
# 1008       Bob Bobson
# 1009     Anne Anthony
# 1010     Anne Anthony
#
# [1011 rows x 11 columns]

# %%
df.describe()
# Out:
#          Weight kg  Body Length cm  Animal code    Latitude   Longitude
# count   984.000000      984.000000          0.0  913.000000  913.000000
# mean     39.745503       39.107724          NaN   49.393369   18.203280
# std     156.290076       58.628601          NaN    7.168900    3.899601
# min      -0.252000      -19.000000          NaN  -78.582973   11.074008
# 25%       0.293000       19.000000          NaN   48.186913   14.384559
# 50%       0.331500       21.000000          NaN   49.560723   18.944015
# 75%       0.800000       23.000000          NaN   52.212433   21.033243
# max    1100.000000      350.000000          NaN   52.853843   34.896734

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Animal type       991 non-null    object
#  1   Country           999 non-null    object
#  2   Weight kg         984 non-null    float64
#  3   Body Length cm    984 non-null    float64
#  4   Gender            992 non-null    object
#  5   Animal code       0 non-null      float64
#  6   Latitude          913 non-null    float64
#  7   Longitude         913 non-null    float64
#  8   Animal name       52 non-null     object
#  9   Observation date  1011 non-null   object
#  10  Data compiled by  1011 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 87.0+ KB

# %% [markdown]
# ## Dropping

# %%
df = df.drop(columns=["Animal code", "Animal name"])
df = df.dropna()
df = df.drop_duplicates()
df
# Out:
#           Animal type  Country  Weight kg  Body Length cm          Gender  \
# 2      European bison   Poland    930.000           335.0            male
# 3      European bison   Poland    909.000           311.0  not determined
# 4     European bison™   Poland    581.000           277.0          female
# 5     European bisson   Poland    900.000           295.0            male
# 6     European buster   Poland    620.000           250.0          female
# ...               ...      ...        ...             ...             ...
# 1005         hedgehog  Hungary      0.900            23.0            male
# 1006     red squirrel   Poland      0.346            20.0          female
# 1007         hedgehog  Germany      1.000            23.0          female
# 1008         hedgehog  Germany      0.500            17.0          female
# 1010         hedgehog  Hungary      0.900            16.0          female
#
#        Latitude  Longitude Observation date Data compiled by
# 2     52.828845  23.820144       01.03.2024     Anne Anthony
# 3     52.830509  23.826849       01.03.2024     Anne Anthony
# 4     52.834109  23.807093       01.03.2024     Anne Anthony
# 5     52.834759  23.817201       01.03.2024     Anne Anthony
# 6     52.834960  23.820750       01.03.2024     Anne Anthony
# ...         ...        ...              ...              ...
# 1005  47.510055  18.944356       7 May 2024     Anne Anthony
# 1006  52.212001  21.033187       7 May 2024     Anne Anthony
# 1007  49.561356  11.105334       7 May 2024       Bob Bobson
# 1008  49.561569  11.087046       7 May 2024       Bob Bobson
# 1010  47.509860  18.939943       8 May 2024     Anne Anthony
#
# [739 rows x 9 columns]

# %% [markdown]
# ## Renaming

# %%
df["Animal type"].unique()
# Out:
# array(['European bison', 'European bison™', 'European bisson',
#        'European buster', 'lynx', 'lynx?', 'red squirel', 'red squirrel',
#        'red squirrell', 'hedgehog', 'wedgehod', 'ledgehod'], dtype=object)

# %%
df["Country"].unique()
# Out:
# array(['Poland', 'Hungary', 'PL', 'Slovakia', 'Czech Republic', 'Czech',
#        'Hungry', 'HU', 'Germany', 'Australia', 'Austria', 'CZ', 'DE',
#        'CC'], dtype=object)

# %%
df["Observation date"].unique()
# Out:
# array(['01.03.2024', '02.03.2024', '03.03.2024', '04.03.2024',
#        '05.03.2024', '06.03.2024', '07.03.2024', '08.03.2024',
#        '09.03.2024', '10.03.2024', '11.03.2024', '12.03.2024',
#        '13.03.2024', '14.03.2024', '15.03.2024', '16.03.2024',
#        '17.03.2024', '18.03.2024', '19.03.2024', '20.03.2024',
#        '21.03.2024', '22.03.2024', '23.03.2024', '24.03.2024',
#        '25.03.2024', '26.03.2024', '27.03.2024', '28.03.2024',
#        '29.03.2024', '30.03.2024', '31.03.2024', '01.04.2024',
#        '02.04.2024', '03.04.2024', '04.04.2024', '05.04.2024',
#        '06.04.2024', '07.04.2024', '08.04.2024', '09.04.2024',
#        '10.04.2024', '11.04.2024', '12.04.2024', '13.04.2024',
#        '14.04.2024', '15.04.2024', '16.04.2024', '17.04.2024',
#        '18.04.2024', '19.04.2024', '20.04.2024', '21.04.2024',
#        '22.04.2024', '23.04.2024', '24.04.2024', '25.04.2024',
#        '26.04.2024', '27.04.2024', '28.04.2024', '29.04.2024',
#        '30.04.2024', '09.05.2024', '10.05.2024', '11.05.2024',
#        '12.05.2024', '13.05.2024', '14.05.2024', '15.05.2024',
#        '16.05.2024', '17.05.2024', '18.05.2024', '19.05.2024',
#        '20.05.2024', '21.05.2024', '22.05.2024', '23.05.2024',
#        '24.05.2024', '26.05.2024', '27.05.2024', '28.05.2024',
#        '29.05.2024', '30.05.2024', '31.05.2024', '01.06.2024',
#        '02.06.2024', '03.06.2024', '05.06.2024', '06.06.2024',
#        '07.06.2024', '08.06.2024', '10.06.2024', '11.06.2024',
#        '19.06.2024', '30.06.2024', '03.07.2024', '05.07.2024',
#        '03.08.2024', '03.09.2024', '03.11.2024', '1 May 2024',
#        '2 may 2024', '3 May 2024', '4 May 2024', '5 May 2024',
#        '6 May 2024', '7 May 2024', '8 May 2024'], dtype=object)

# %%
df["Animal type"] = df["Animal type"].replace({
    "European bison™": "European bison",
    "European bisson": "European bison", 
    "European buster": "European bison",
    "lynx?": "lynx",
    "red squirrel": "red squirel",
    "red squirrell": "red squirel",
    "wedgehod": "hedgehog",
    "ledgehod": "hedgehog"
})

df["Country"] = df["Country"].replace({
    "PL": "Poland",
    "Hungry": "Hungary",
    "HU": "Hungary",
    "Slovakia": "Slovakia",
    "Czech": "Czech Republic",
    "CZ": "Czech Republic",
    "DE": "Germany",
    "CC": "Australia"
})

# df["Gender"] = df["Gender"].replace("not determined", None)

df["Observation date"] = df["Observation date"].replace({
    "1 May 2024": "01.05.2024",
    "2 may 2024": "02.05.2024",
    "3 May 2024": "03.05.2024",
    "4 May 2024": "04.05.2024",
    "5 May 2024": "05.05.2024",
    "6 May 2024": "06.05.2024",
    "7 May 2024": "07.05.2024",
    "8 May 2024": "08.05.2024"
})

df["Observation date"] = pd.to_datetime(df["Observation date"], dayfirst=True, errors='coerce')

df
# Out:
#          Animal type  Country  Weight kg  Body Length cm          Gender  \
# 2     European bison   Poland    930.000           335.0            male
# 3     European bison   Poland    909.000           311.0  not determined
# 4     European bison   Poland    581.000           277.0          female
# 5     European bison   Poland    900.000           295.0            male
# 6     European bison   Poland    620.000           250.0          female
# ...              ...      ...        ...             ...             ...
# 1005        hedgehog  Hungary      0.900            23.0            male
# 1006     red squirel   Poland      0.346            20.0          female
# 1007        hedgehog  Germany      1.000            23.0          female
# 1008        hedgehog  Germany      0.500            17.0          female
# 1010        hedgehog  Hungary      0.900            16.0          female
#
#        Latitude  Longitude Observation date Data compiled by
# 2     52.828845  23.820144       2024-03-01     Anne Anthony
# 3     52.830509  23.826849       2024-03-01     Anne Anthony
# 4     52.834109  23.807093       2024-03-01     Anne Anthony
# 5     52.834759  23.817201       2024-03-01     Anne Anthony
# 6     52.834960  23.820750       2024-03-01     Anne Anthony
# ...         ...        ...              ...              ...
# 1005  47.510055  18.944356       2024-05-07     Anne Anthony
# 1006  52.212001  21.033187       2024-05-07     Anne Anthony
# 1007  49.561356  11.105334       2024-05-07       Bob Bobson
# 1008  49.561569  11.087046       2024-05-07       Bob Bobson
# 1010  47.509860  18.939943       2024-05-08     Anne Anthony
#
# [739 rows x 9 columns]

# %% [markdown]
# ## Handling data

# %%
df.loc[df["Weight kg"] < 0, "Weight kg"] *= -1
df.loc[df["Body Length cm"] < 0, "Body Length cm"] *= -1

# %% [markdown]
# ## Data visualization

# %%
sns.countplot(x ="Animal type", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Animal type', ylabel='count'>

# %%
sns.countplot(x ="Data compiled by", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Data compiled by', ylabel='count'>

# %%
count_df = df.groupby(['Observation date', 'Gender']).size().reset_index(name='count')

plt.figure(figsize=(12, 6))
sns.lineplot(x='Observation date', y='count', hue="Gender", data=count_df, marker='o')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
count_df = df.groupby(['Observation date', 'Data compiled by']).size().reset_index(name='count')

plt.figure(figsize=(12, 6))
sns.lineplot(x='Observation date', y='count', hue="Data compiled by", data=count_df, marker='o')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
sns.countplot(x ="Country", hue = "Animal type", data = df)
plt.subplot(2, 1, 2)
sns.countplot(x ="Animal type", hue = "Country", data = df)
# Out:
# <Axes: xlabel='Animal type', ylabel='count'>

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 2, 1)
plt.title("European bison")
sns.histplot(data=df[df["Animal type"] == "European bison"], x="Weight kg", hue="Gender", multiple="dodge", kde=True)
plt.subplot(2, 2, 2)
plt.title("lynx")
sns.histplot(data=df[df["Animal type"] == "lynx"], x="Weight kg", hue="Gender", multiple="dodge", kde=True)
plt.subplot(2, 2, 3)
plt.title("red squirel")
sns.histplot(data=df[df["Animal type"] == "red squirel"], x="Weight kg", hue="Gender", multiple="dodge", kde=True)
plt.subplot(2, 2, 4)
plt.title("hedgehog")
sns.histplot(data=df[df["Animal type"] == "hedgehog"], x="Weight kg", hue="Gender", multiple="dodge", kde=True)
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 2, 1)
plt.title("European bison")
sns.histplot(data=df[df["Animal type"] == "European bison"], x="Body Length cm", hue="Gender", multiple="dodge", kde=True)
plt.subplot(2, 2, 2)
plt.title("lynx")
sns.histplot(data=df[df["Animal type"] == "lynx"], x="Body Length cm", hue="Gender", multiple="dodge", kde=True)
plt.subplot(2, 2, 3)
plt.title("red squirel")
sns.histplot(data=df[df["Animal type"] == "red squirel"], x="Body Length cm", hue="Gender", multiple="dodge", kde=True)
plt.subplot(2, 2, 4)
plt.title("hedgehog")
sns.histplot(data=df[df["Animal type"] == "hedgehog"], x="Body Length cm", hue="Gender", multiple="dodge", kde=True)
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 2, 1)
plt.title("European bison")
sns.boxplot(data=df[df["Animal type"] == "European bison"], x="Weight kg", hue="Gender", fill=False)
plt.subplot(2, 2, 2)
plt.title("lynx")
sns.boxplot(data=df[df["Animal type"] == "lynx"], x="Weight kg", hue="Gender", fill=False)
plt.subplot(2, 2, 3)
plt.title("red squirel")
sns.boxplot(data=df[df["Animal type"] == "red squirel"], x="Weight kg", hue="Gender", fill=False)
plt.subplot(2, 2, 4)
plt.title("hedgehog")
sns.boxplot(data=df[df["Animal type"] == "hedgehog"], x="Weight kg", hue="Gender", fill=False)
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 2, 1)
plt.title("European bison")
sns.boxplot(data=df[df["Animal type"] == "European bison"], x="Body Length cm", hue="Gender", fill=False)
plt.subplot(2, 2, 2)
plt.title("lynx")
sns.boxplot(data=df[df["Animal type"] == "lynx"], x="Body Length cm", hue="Gender", fill=False)
plt.subplot(2, 2, 3)
plt.title("red squirel")
sns.boxplot(data=df[df["Animal type"] == "red squirel"], x="Body Length cm", hue="Gender", fill=False)
plt.subplot(2, 2, 4)
plt.title("hedgehog")
sns.boxplot(data=df[df["Animal type"] == "hedgehog"], x="Body Length cm", hue="Gender", fill=False)
plt.show()

# %%
sns.pairplot(df, vars=["Weight kg", "Body Length cm"], hue="Animal type", height=2, aspect=1.5)

# %% [markdown]
# ### Geo-visualization

# %%
map = folium.Map(location=[54, 18], zoom_start=4)
for i, row in df.iterrows():
    if row["Animal type"]=="red squirrel":
        folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row["Animal type"],icon=folium.Icon(color='orange')).add_to(map)
    elif row["Animal type"]=="hedgehog":
        folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row["Animal type"],icon=folium.Icon(color='lightgray')).add_to(map)
    elif row["Animal type"]=="lynx":
        folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row["Animal type"],icon=folium.Icon(color='blue')).add_to(map)
    else:
        folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row["Animal type"],icon=folium.Icon(color='black')).add_to(map)
folium.plugins.Geocoder().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e0b4f936a5c20afe8bb065782e071da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e0b4f936a5c20afe8bb065782e071da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e0b4f936a5c20afe8bb065782e071da = L.map(
#                 &quot;map_6e0b4f936a5c20afe8bb065782e071da&quot;,
#                 {
#                     center: [54.0, 18.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f78e79753391b57cdf557cb63788b20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f78e79753391b57cdf557cb63788b20.addTo(map_6e0b4f936a5c20afe8bb065782e071da);
#
#
#             var marker_9b31a2a49a4afb8c1deaa5bd64d938a5 = L.marker(
#                 [52.828845, 23.820144],
#                 {
# }
#             ).addTo(map_6e0b4f936a5c20afe8bb065782e071da);
#
#
#             var icon_7f66237bb6bafa3072d97d829644868e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_432243ed7658ce2efbc80f35bd3c0229 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6f621c32503b2210f0e8a481c83ded8 = $(`&lt;div id=&quot;html_c6f621c32503b2210f0e8a481c83ded8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;European bison&lt;/div&gt;`)[0];
#                 popup_432243ed7658ce2efbc80f35bd3c0229.setContent(html_c6f621c32503b2210f0e8a481c83ded8);
#
#
#
#         marker_9b31a2a49a4afb8c1deaa5bd64d938a5.bindPopup(popup_432243ed7658ce2efbc80f35bd3c0229)
#         ;
#
#
#
#
#                 marker_9b31a2a49a4afb8c1deaa5bd64d938a5.setIcon(icon_7f66237bb6bafa3072d97d829644868e);
#
#
#             var marker_e0e71b485ad1faae75aced7a7f9a0fbd = L.marker(
#                 [52.830509, 23.826849],
#                 {
# }
#             ).addTo(map_6e0b4f936a5c20afe8bb065782e071da);
#
#
#             var icon_ca9b925e40553732d65b11409058215a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0be2a6ec1eefe9bc70ce5c7e46ccccec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45fff2e3c3c54a0fff9a121d0393c8cd = $(`&lt;div id=&quot;html_45fff2e3c3c54a0fff9a121d0393c8cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;European bison&lt;/div&gt;`)[0];
#                 popup_0be2a6ec1eefe9bc70ce5c7e46ccccec.setContent(html_45fff2e3c3c54a0fff9a121d0393c8cd);
#
#
#
#         marker_e0e71b485ad1faae75aced7a7f9a0fbd.bindPopup(popup_0be2a6ec1eefe9bc70ce5c7e46ccccec)
#         ;
#
#
#
#
#                 marker_e0e71b485ad1faae75aced7a7f9a0fbd.setIcon(icon_ca9b925e40553732d65b11409058215a);
#
#
#             var marker_cad8bd3b7b952067e4e7f6d997a1bf37 = L.marker(
#                 [52.834109, 23.807093],
#                 {
# }
#             ).addTo(map_6e0b4f936a5c20afe8bb065782e071da);
#
#
#             var icon_a6437b1a1ec370ea0140efcd656b9cbf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_94d1eecdf467b27a68a668a3a617d396 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c1da0fb301782bfcd3e3fd8e079c4e4 = $(`&lt;div id=&quot;html_5c1da0fb301782bfcd3e3fd8e079c4e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;European bison&lt;/div&gt;`)[0];
#                 popup_94d1eecdf467b27a68a668a3a617d396.setContent(html_5c1da0fb301782bfcd3e3fd8e079c4e4);
#
#
#
#         marker_cad8bd3b7b952067e4e7f6d997a1bf37.bi

# %%
map2 = Map(location=[54, 18], title='cartodbpositron', zoom_start=6)
HeatMap(data=df[['Latitude', 'Longitude']], radius=10).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41c8572a8446cab466b87db224600ab9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41c8572a8446cab466b87db224600ab9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41c8572a8446cab466b87db224600ab9 = L.map(
#                 &quot;map_41c8572a8446cab466b87db224600ab9&quot;,
#                 {
#                     center: [54.0, 18.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;title&quot;: &quot;cartodbpositron&quot;,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab3d208a2464acee6f824b9860af3bc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab3d208a2464acee6f824b9860af3bc7.addTo(map_41c8572a8446cab466b87db224600ab9);
#
#
#             var heat_map_d24b9d52d7c3987bf2d7e62770b429c7 = L.heatLayer(
#                 [[52.828845, 23.820144], [52.830509, 23.826849], [52.834109, 23.807093], [52.834759, 23.817201], [52.83496, 23.82075], [48.505494, 20.551966], [48.506529, 20.554548], [52.241273, 21.055745], [52.24206, 21.057802], [52.240035, 21.056188], [52.24056, 21.055899], [52.240833, 21.052093], [52.241358, 21.056352], [52.241905, 21.050727], [47.511401, 18.949119], [52.24192, 21.056347], [49.054684, 22.417189], [49.053629, 22.421831], [49.053489, 22.415229], [49.054166, 22.422852], [49.052731, 22.422675], [49.055974, 22.415985], [49.053342, 22.423867], [49.056471, 22.422475], [50.636564, 14.834553], [49.055537, 22.419428], [50.636869, 14.844555], [50.644733, 14.835753], [50.635766, 14.844247], [48.185353, 17.08322], [50.642843, 14.84124], [48.504128, 20.568479], [52.809851, 23.858071], [50.641008, 14.836529], [50.643406, 14.836495], [50.638945, 14.845452], [50.639869, 14.849702], [50.643039, 14.840662], [50.637879, 14.838429], [50.643254, 14.84373], [50.643854, 14.837155], [50.635584, 14.837072], [50.642723, 14.837229], [50.639389, 14.8444], [48.409308, 18.832606], [47.510799, 18.945583], [50.637375, 14.839785], [48.406304, 18.842851], [48.18769, 17.086471], [52.834741, 23.826716], [48.503795, 20.555932], [48.503062, 20.551698], [48.503498, 20.539662], [48.509298, 20.551977], [52.214679, 21.033021], [48.504169, 20.559452], [48.505251, 20.551473], [48.502584, 20.532518], [48.505512, 20.538038], [48.50578, 20.546466], [48.502091, 20.547521], [48.505494, 20.536362], [52.241203, 21.050999], [52.240018, 21.05239], [52.239931, 21.056703], [52.241856, 21.053078], [52.240453, 21.055847], [52.241638, 21.055998], [48.502803, 20.548668], [52.240497, 21.055991], [50.635501, 14.838158], [50.638142, 14.849689], [49.937872, 14.179825], [48.185194, 17.083142], [48.503043, 20.561567], [52.240867, 21.054339], [52.240522, 21.057552], [47.507002, 18.950091], [47.507557, 18.942066], [50.107284, 14.346127], [48.413226, 18.848128], [48.409023, 18.84399], [48.406733, 18.838754], [48.40459, 18.846849], [48.408318, 18.844383], [48.412458, 18.832425], [48.406551, 18.837137], [48.405516, 18.850994], [52.834423, 23.827103], [52.214521, 21.031889], [52.214934, 21.032106], [48.511532, 20.539112], [52.241638, 21.057329], [52.241235, 21.057356], [50.106942, 14.348502], [50.107223, 14.34732], [50.106379, 14.347645], [50.106579, 14.346283], [48.188008, 17.085312], [48.185298, 17.084072], [52.831879, 23.826297], [48.50509, 20.539448], [48.504425, 20.548744], [48.505617, 20.541054], [48.503254, 20.555951], [48.502359, 20.563385], [48.511048, 20.567209], [48.501574, 20.532455], [52.808579, 23.843768], [-2.023546, 34.896734], [48.505406, 20.535848], [48.503917, 20.536503], [52.240616, 21.054902], [50.636161, 14.846951], [50.642592, 14.85014], [50.636423, 14.847287], [50.106607, 14.347909], [50.106925, 14.346629], [50.107284, 14.347676], [49.938634, 14.181813], [48.506913, 20.540427], [52.214365, 21.031462], [47.507023, 18.940532], [50.106811, 14.348513], [50.107278, 14.348461], [52.828561, 23.816861], [52.833261, 23.815203], [52.21441, 21.032484], [52.214452, 21.034505], [48.508239, 20.567914], [48.507503, 20.551726], [52.814984, 23.840681], [52.812647, 23.863299], [52.241375, 21.050845], [47.50938, 18.949607], [50.106583, 14.346471], [50.10696, 14.346126], [50.106311, 14.346906], [49.937416, 14.181449], [48.51108, 20.567192], [48.50529, 20.566169], [48.502486, 20.562565], [48.509272, 20.551952], [48.50118, 20.557432], [49.938707, 14.182507], [49.937531, 14.180359], [49.93789, 14.180882], [49.93734, 14.18071], [52.834112, 23.825722], [48.505634, 20.543417], [52.214968, 21.030987], [48.

# %%
animal_summary = df.groupby(["Country"]).agg(Observations_by_country=("Country","count"))
animal_summary = animal_summary.reset_index()
animal_summary
# Out:
#           Country  Observations_by_country
# 0       Australia                        8
# 1         Austria                       66
# 2  Czech Republic                      112
# 3         Germany                      107
# 4         Hungary                      113
# 5          Poland                      183
# 6        Slovakia                      150

# %%
countries_geojson_url = ("http://geojson.xyz/naturalearth-3.3.0/ne_50m_admin_0_countries.geojson"
)
map3 = folium.Map(location=(50, 10), zoom_start=6, tiles="cartodb positron")
folium.Choropleth(
    geo_data=countries_geojson_url,
    data=animal_summary,
    columns=["Country", "Observations_by_country"],
    key_on="feature.properties.name_long",
    fill_color="RdYlGn_r",
    nan_fill_color="white",
    legend_name="Animals spotted by country"
).add_to(map)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_834e1c9a310c51232dfc55f4de2c6ef5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_834e1c9a310c51232dfc55f4de2c6ef5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_834e1c9a310c51232dfc55f4de2c6ef5 = L.map(
#                 &quot;map_834e1c9a310c51232dfc55f4de2c6ef5&quot;,
#                 {
#                     center: [50.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c5767039a0c08ff643960b39b85627e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c5767039a0c08ff643960b39b85627e.addTo(map_834e1c9a310c51232dfc55f4de2c6ef5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save('map_with_tooltips.html')

# %% [markdown]
# ## Data cleaning

# %%
mask = (df["Animal type"] == "lynx") & (df["Weight kg"] > 100)
df = df.drop(df[mask].index)
mask = (df["Animal type"] == "hedgehog") & (df["Body Length cm"] > 100)
df = df.drop(df[mask].index)

df.to_csv("wrecked_data/animal_data_clean.csv", index=False)
