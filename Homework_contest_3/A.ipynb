# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/students_info.csv", index_col="STD_ID")
df = df[~df.index.duplicated()]
df
# Out:
#        Пол Статус Дата выпуска Категория обучения Форма обучения      Шифр  \
# STD_ID
# 99136    Ж    ВЫП   2019-08-31                 БП              Д  31.05.01
# 99112    Ж    ВЫП   2019-08-31                 БП              Д  31.05.01
# 99109    Ж    ВЫП   2019-08-31                 БП              Д  31.05.01
# 99125    Ж    ВЫП   2019-08-31                 БП              Д  31.05.01
# 100676   М    ВЫП   2019-08-31                 БП              Д  31.05.01
# ...     ..    ...          ...                ...            ...       ...
# 100678   Ж     СТ          NaN                 БП              Д  31.05.01
# 100663   Ж     СТ          NaN                ДОГ              Д  31.05.01
# 191630   Ж     СТ          NaN                ДОГ              Д  31.05.01
# 191625   Ж     СТ          NaN                ДОГ              Д  31.05.01
# 194978   Ж     СТ          NaN                ДОГ              Д  31.05.01
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5104 entries, 99136 to 194978
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Пол                          5103 non-null   object
#  1   Статус                       5103 non-null   object
#  2   Дата выпуска                 455 non-null    object
#  3   Категория обучения           5103 non-null   object
#  4   Форма обучения               5103 non-null   object
#  5   Шифр                         5103 non-null   object
#  6   направление (специальность)  5103 non-null   object
#  7   Образование                  4913 non-null   object
#  8   Дата выдачи                  4878 non-null   object
#  9   Что именно закончил          4913 non-null   object
# dtypes: object(10)
# memory usage: 438.6+ KB

# %%
df["Статус"].value_counts()
# Out:
# Статус
# СТ     4648
# ВЫП     455
# Name: count, dtype: int64

# %%
df.query("Пол == 'М' and Статус == 'СТ'")["направление (специальность)"].value_counts()
# Out:
# направление (специальность)
# Лечебное дело                                                                256
# Стоматология                                                                 186
# Юриспруденция                                                                173
# Строительство                                                                140
# Теплоэнергетика и теплотехника                                               102
# Педагогическое образование                                                    79
# Агроинженерия                                                                 76
# Эксплуатация транспортно-технологических машин и комплексов                   76
# Менеджмент                                                                    75
# Информатика и вычислительная техника                                          69
# Конструирование и технология электронных средств                              66
# ...

# %%
df.query("Пол == 'Ж' and Статус == 'СТ'")["направление (специальность)"].value_counts()
# Out:
# направление (специальность)
# Лечебное дело                                                                490
# Педагогическое образование (с двумя профилями подготовки)                    249
# Юриспруденция                                                                219
# Стоматология                                                                 218
# Педагогическое образование                                                   174
# Экономика                                                                    132
# Специальное (дефектологическое) образование                                  112
# Лингвистика                                                                   86
# Журналистика                                                                  81
# Менеджмент                                                                    81
# Фармация                                                                      68
# ...

# %%
df[df.isna().all(axis=1)]
# Out:
#         Пол Статус Дата выпуска Категория обучения Форма обучения Шифр  \
# STD_ID
# 92222   NaN    NaN          NaN                NaN            NaN  NaN
#
#        направление (специальность) Образование Дата выдачи Что именно закончил
# STD_ID
# 92222                          NaN         NaN         NaN                 NaN

# %%
df["направление (специальность)"].unique().shape
# Out:
# (45,)

# %%
df["Пол"].value_counts()
# Out:
# Пол
# Ж    3015
# М    2088
# Name: count, dtype: int64
